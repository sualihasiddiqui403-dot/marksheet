# %%
# !pip install -q google-generativeai



import google.generativeai as genai
from PIL import Image
import requests
from IPython.display import display


API_KEY = "AIzaSyAMU2pE-YjVjOCghWjsYO8a4tyhJKhiQtY"

genai.configure(api_key=API_KEY)

image_url = "https://richskxn.co.uk/cdn/shop/articles/Spf_sunscreen_skincare_essentials.jpg?v=1673605386"
image = Image.open(requests.get(image_url,stream=True).raw)
display(image)

model = genai.GenerativeModel("gemini-2.0-flash-exp")

prompt = "List all the skincare products visible in this picture with their benefits in bullet points."
response = model.generate_content([prompt,image])

print(response.text)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x1200>
# Here is a list of the visible skincare products and their benefits:
#
# *   **Supergoop! Glow Stick Sunscreen SPF 50:**
#     *   Provides broad-spectrum SPF 50 protection.
#     *   Offers a healthy-looking glow.
#     *   Easy to apply and reapply.
#
# *   **Supergoop! Every Single Face Watery Lotion SPF 50:**
#     *   Broad-spectrum SPF 50 protection.
#     *   Lightweight and hydrating formula.
#     *   Suitable for all skin types.
#
# *   **Cocokind Daily SPF:**
#     *   Provides broad-spectrum SPF protection.
#     *   May contain moisturizing and nourishing ingredients.
#
# *   **Laneige Hydro UV Defense Sunscreen Broad Spectrum SPF 50+ PA++++:**
#     *   Provides broad-spectrum SPF 50+ PA++++ protection.
#     *   Hydrating formula.
#
# *   **Supergoop! Unseen Sunscreen SPF 40:**
#     *   Broad-spectrum SPF 40 protection.
#     *   Weightless, invisible formula.
#     *   Can be used as a makeup primer.
# ...
